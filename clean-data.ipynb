# %%
import pandas as pd
import numpy as np

print('numpy version:', np.__version__)
print('pandas version:', pd.__version__)
# Out:
# numpy version: 1.24.2
# pandas version: 1.5.3

# %% [markdown]
# ## Load data

# %%
# carregando os dados
vendas = pd.read_csv('data/vendas.csv', skiprows=3, header=1, usecols=[2,3,4,5,6,7,8,9])
consumidores = pd.read_csv('data/consumidores.csv')
produto = pd.read_csv('data/produto.csv')
lojas = pd.read_csv('data/lojas.csv')

# %% [markdown]
# ## Merge dataframes
# Possíveis uniões
#
# * vendas e consumidores podem ser unidos pela coluna 'ClientID'.
# * vendas e lojas podem ser unidos pela coluna 'StoreID'.
# * vendas e produto podem ser unidos pela coluna 'ProductID'.

# %%
print("Vendas columns:", vendas.columns)
print("Consumidores columns:", consumidores.columns)
print("Lojas columns:", lojas.columns)
print("Produtos columns:", produto.columns)
# Out:
# Vendas columns: Index(['ID', 'ProductID', 'ClientID', 'Discount', 'UnitPrice', 'Quantity',
#        'StoreID', 'Date'],
#       dtype='object')
# Consumidores columns: Index(['ID', 'City', 'State', 'DateOfBirth', 'Sex'], dtype='object')
# Lojas columns: Index(['ID', 'Name', 'State'], dtype='object')
# Produtos columns: Index(['ID', 'Name', 'Size'], dtype='object')

# %%
columns_to_suffix = ['City','State']
consumidores = consumidores.rename(columns={col: f'{col}_cons' for col in columns_to_suffix})

# %%
columns_to_suffix = ['Name','State']
lojas = lojas.rename(columns={col: f'{col}_loj' for col in columns_to_suffix})

# %%
columns_to_suffix = ['Name']
produto = produto.rename(columns={col: f'{col}_pro' for col in columns_to_suffix})

# %%
vendas_consumidor = pd.merge(vendas, consumidores, left_on='ClientID', right_on='ID',suffixes=("_vend", "_cons"))
vendas_consumidor = vendas_consumidor.drop('ID_cons', axis=1)

vendas_lojas = pd.merge(vendas, lojas, left_on='StoreID', right_on='ID',suffixes=("_vend", "_loja"))
vendas_lojas = vendas_lojas.drop('ID_loja', axis = 1)

vendas_produto = pd.merge(vendas, produto, left_on='ProductID', right_on='ID',suffixes=("_vend", "_prod"))
vendas_produto =  vendas_produto.drop('ID_prod', axis = 1)

combined_df = vendas_consumidor.merge(vendas_lojas, on=['ID_vend', 'ProductID', 'ClientID', 'Discount', 'UnitPrice', 'Quantity', 'StoreID', 'Date'])
combined_df = combined_df.merge(vendas_produto, on=['ID_vend', 'ProductID', 'ClientID', 'Discount', 'UnitPrice', 'Quantity', 'StoreID', 'Date'])

# %%
combined_df.head()
# Out:
#                             ID_vend                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#    ClientID Discount UnitPrice  Quantity  StoreID        Date      City_cons  \
# 0     14001     0,08     249,2         1        4  12/10/2018       Curitiba
# 1     14001      0,1     162,4         1        4   4/25/2019       Curitiba
# 2     14001      0,1     194,6         1        4   7/17/2019       Curitiba
# 3     14002      0,1     201,6         2        1   4/10/2018  Florianópolis
# 4     14002      0,1       406         1        1   1/21/2019  Florianópolis
#
#   State_cons DateOfBirth    Sex       Name_loj State_loj         Name_pro Size
# 0         PR   6/28/1985  Homem       Curitiba        PR       Tempestade    G
# 1         PR   6/28/1985  Homem       Curitiba        PR           Thanos    G
# 2         PR   6/28/1985  Homem       Curitiba        PR  Capitão América    P
# 3         SC   1/10/1987  Homem  Florianópolis        SC        Wolverine    G
# 4         SC   1/10/1987  Homem  Florianópolis        SC           Naruto    G

# %%
# substituir vígula por ponto para se enquadrar no padrão internacional
combined_df.Discount = combined_df.Discount.str.replace(',', '.')
combined_df.UnitPrice = combined_df.UnitPrice.str.replace(',', '.')

# %% [markdown]
# ## Convert data types

# %%
def convert_columns_types(df):
    # Dicionário com os tipos de colunas
    column_types = {
        'date': ['Date', 'DateOfBirth'],
        'numeric': ['Discount', 'UnitPrice', 'Quantity'],
        'category': ['ID_vend', 'ProductID', 'ClientID','StoreID', 'City_cons', 'State_cons','Sex','Name_loj', 'State_loj', 'Name_pro', 'Size']
    }

    # Função para converter colunas de data
    def convert_date_columns(df, columns):
        for col in columns:
            if col in df.columns:
                df[col] = pd.to_datetime(df[col], format='%m/%d/%Y')
        return df

    # Função para converter colunas numéricas
    def convert_numeric_columns(df, columns):
        for col in columns:
            if col in df.columns:
                df[col] = pd.to_numeric(df[col])
        return df

    # Função para converter colunas de categoria
    def convert_category_columns(df, columns):
        for col in columns:
            if col in df.columns:
                df[col] = df[col].astype('category')
        return df

    # Converter colunas de acordo com os tipos definidos no dicionário
    df = convert_date_columns(df, column_types['date'])
    df = convert_numeric_columns(df, column_types['numeric'])
    df = convert_category_columns(df, column_types['category'])

    return df

# Exemplo de uso da função
combined_df_converted = convert_columns_types(combined_df.copy())
combined_df_converted
# Out:
#                                 ID_vend                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
#       ClientID  Discount  UnitPrice  Quantity StoreID       Date  \
# 0        14001      0.08      249.2         1       4 2018-12-10
# 1        14001      0.10      162.4         1       4 2019-04-25
# 2        14001      0.10      194.6         1       4 2019-07-17
# 3        14002      0.10      201.6         2       1 2018-04-10
# 4        14002      0.10      406.0         1       1 2019-01-21
# ...        ...       ...        ...       ...     ...        ...
# 32748    28694      0.08      218.4         1       4 2018-12-02
# 32749    28694      0.08      210.0         1       4 2018-12-05
# 32750    28694      0.08      148.4         1       4 2019-08-01
# 32751    28694      0.10      218.4         2       4 2019-11-25
# 32752    28695      0.10      254.8         1       4 2018-07-04
#
#            City_cons State_cons DateOfBirth    Sex       Name_loj State_loj  \
# 0           Curitiba         PR  1985-06-28  Homem       Curitiba        PR
# 1           Curitiba         PR  1985-06-28  Homem       Curitiba        PR
# 2           Curitiba         PR  1985-06-28  Homem       Curitiba        PR
# 3      Florianópolis         SC  1987-01-10  Homem  Florianópolis        SC
# 4      Florianópolis         SC  1987-01-10  Homem  Florianópolis        SC
# ...              ...        ...         ...    ...            ...       ...
# 32748       Curitiba         PR  1982-10-22  Homem       Curitiba        PR
# 32749       Curitiba         PR  1982-10-22  Homem       Curitiba        PR
# 32750       Curitiba         PR  1982-10-22  Homem       Curitiba        PR
# 32751       Curitiba         PR  1982-10-22  Homem       Curitiba        PR
# 32752       Curitiba         PR  1961-10-24  Homem       Curitiba        PR
#
#                Name_pro Size
# 0            Tempestade    G
# 1                Thanos    G
# 2       Capitão América    P
# 3             Wolverine    G
# 4                Naruto    G
# ...                 ...  ...
# 32748           Bazinga    M
# 32749          Iron Man    G
# 32750  Mulher-Maravilha    G
# 32751           Bazinga    G
# 32752          Deadpool    M
#
# [32753 rows x 16 columns]

# %% [markdown]
# ## Create new variables

# %%
combined_df_converted['Revenue'] = combined_df_converted['UnitPrice'] * (1 - combined_df_converted['Discount']) * combined_df_converted['Quantity']

# %%
combined_df_converted['Year'] = combined_df_converted['Date'].dt.year
combined_df_converted['Month'] = combined_df_converted['Date'].dt.month
combined_df_converted['Day'] = combined_df_converted['Date'].dt.day

# %%
combined_df_converted['Age'] = ((combined_df_converted['Date'] - combined_df_converted['DateOfBirth']) / pd.Timedelta(days=365)).astype(int)

# %%
combined_df_converted.head()
# Out:
#                             ID_vend                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#   ClientID  Discount  UnitPrice  Quantity StoreID       Date      City_cons  \
# 0    14001      0.08      249.2         1       4 2018-12-10       Curitiba
# 1    14001      0.10      162.4         1       4 2019-04-25       Curitiba
# 2    14001      0.10      194.6         1       4 2019-07-17       Curitiba
# 3    14002      0.10      201.6         2       1 2018-04-10  Florianópolis
# 4    14002      0.10      406.0         1       1 2019-01-21  Florianópolis
#
#   State_cons DateOfBirth    Sex       Name_loj State_loj         Name_pro  \
# 0         PR  1985-06-28  Homem       Curitiba        PR       Tempestade
# 1         PR  1985-06-28  Homem       Curitiba        PR           Thanos
# 2         PR  1985-06-28  Homem       Curitiba        PR  Capitão América
# 3         SC  1987-01-10  Homem  Florianópolis        SC        Wolverine
# 4         SC  1987-01-10  Homem  Florianópolis        SC           Naruto
#
#   Size  Revenue  Age
# 0    G  229.264   33
# 1    G  146.160   33
# 2    P  175.140   34
# 3    G  362.880   31
# 4    G  365.400   32

# %% [markdown]
# ## Save

# %%
combined_df_converted.to_parquet('data/cleaned.parquet')
